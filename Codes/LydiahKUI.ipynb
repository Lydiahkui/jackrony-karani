# %%
import pandas as pd
import numpy as np

# %%
def lydiah(x):
    if (x <=10) & (x >=0):
        return 'Found in Between 0 and 10'
    else:
        return 'Not in  the Range'

# %%
lydiah(0)
# Out:
# 'Found in Between 0 and 10'

# %%
def lydiah(x):
    if (x <=10) & (x >=0):
        return 'Found in Between 0 and 10'
    else:
        return 'Not in  the Range'

# %%
def adam_eve(x):
    if x % 2 == 0:
        return f"{x} is an even number"
    else:
        return f"{x} is an odd number"

# %%
adam_eve(31)
# Out:
# '31 is an odd number'

# %%
def grader(m):
    if m>= 70:
        return "First Class"
    elif m>= 50 :
        return "Pass"
    else:
        return "Failed"

# %%
grader(84)
# Out:
# 'First Class'

# %%
def avg(lst):
    sum_c = 0
    n = 0

    for x in lst:
        sum_c = sum_c + x
        n = n + 1
    avg = sum_c/n

    return avg

# %%
avg([2,4,3])
# Out:
# 3.0

# %%
#A function  to determine even or odd number
def odd_even(x):
    if x % 2 == 0:
        return f"{x} is an even number"
    else:
        return f"{x} is an odd number"

# %%
odd_even(2)
# Out:
# '2 is an even number'

# %%
def grader(score):
    if score >= 70:
        return "First Class"
    elif score >= 50:
        return "Pass"
    elif score >=30:
        return "Fail"
    else:
        return "Joker"

# %%
grader(8)
# Out:
# 'Joker'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def mathematician(x):
    if type(x) == int:
        if x> 10:
            if x %2 == 0:
                return "Even and Greater than 10"
            else:
                return "odd and greater than 10"            
        else:
            return "Smaller than or equal to 10"        
    else:
        return 'Not a number'

# %%
mathematician('Lydia')
# Out:
# 'Not a number'

# %%
type(3)
# Out:
# int
